# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/Gent_autos_inwoners.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
# jaar                      27 non-null float64
# Aantal auto’s             29 non-null int64
# aantal inwoners           22 non-null float64
# Aantal auto’s tov 2000    29 non-null int64
# +/- auto’s                29 non-null int64
# +/- inwoners              21 non-null float64
# ratio                     21 non-null object
# Per 1000 inw              22 non-null object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
data.columns
# Out:
# Index(['jaar', 'Aantal auto’s', 'aantal inwoners', 'Aantal auto’s tov 2000',
#        '+/- auto’s', '+/- inwoners', 'ratio', 'Per 1000 inw'],
#       dtype='object')

# %%
x = data['jaar']
y = data['Aantal auto’s tov 2000']
plt.plot(x, y)

# %%
data2 = pd.read_csv('datasets/Gron_autos_inwoners.csv')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
# jaar                      27 non-null int64
# Aantal auto’s             27 non-null int64
# aantal inwoners           24 non-null float64
# Aantal auto’s tov 2000    27 non-null int64
# +/- auto’s                26 non-null float64
# +/- inwoners              23 non-null float64
# ratio                     23 non-null object
# Per 1000 inw              23 non-null float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
x = data2['jaar']
y = data2['Aantal auto’s tov 2000']
plt.plot(x, y)

# %%
data3 = pd.read_csv('datasets/Leipzig_autos_inwoners.csv')

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
# jaar                      30 non-null int64
# Aantal personenauto’s     24 non-null float64
# aantal inwoners           29 non-null float64
# Aantal auto’s tov 2000    24 non-null float64
# +/- auto’s                24 non-null float64
# +/- inwoners              24 non-null float64
# ratio                     23 non-null object
# Per 1000 inw              23 non-null object
# jaar.1                    17 non-null float64
# totaal                    17 non-null float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ KB

# %%
x = data3['jaar']
y = data3['Aantal personenauto’s']
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(x, y, color='r')
ax.set_xticks([2000, 2005, 2007, 2010, 2015, 2017])
ax.set_xlabel('Years')
#ax.set_yticks([185000, 200000, 210000, 220000, 230000])
ax.set_ylabel('Number of cars in the city')
ax.set_title('Numbers of cars in Leipzig')
plt.show()

# %%
data4 = pd.read_csv('datasets/Verkehr_Kraftfahrzeugbestand.csv')

# %%
data4.columns
# Out:
# Index(['Kennziffer', 'Einheit', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017'],
#       dtype='object')

# %%
my = data4.loc[:,'2005':'2010']

# %%
my.T.plot(legend = 'best', label = 'type', style='--') #T = swap x and y axes (transpose)
